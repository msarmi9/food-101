# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Objective" data-toc-modified-id="Objective-1">Objective</a></span></li><li><span><a href="#About-Food-101" data-toc-modified-id="About-Food-101-2">About Food-101</a></span></li><li><span><a href="#Train-valid-split" data-toc-modified-id="Train-valid-split-3">Train-valid-split</a></span></li><li><span><a href="#Load-Food-101-Dataset" data-toc-modified-id="Load-Food-101-Dataset-4">Load Food-101 Dataset</a></span></li><li><span><a href="#Data-Augmentation" data-toc-modified-id="Data-Augmentation-5">Data Augmentation</a></span></li><li><span><a href="#First-Crack-at-a-Better-Model" data-toc-modified-id="First-Crack-at-a-Better-Model-6">First Crack at a Better Model</a></span><ul class="toc-item"><li><span><a href="#Mixup" data-toc-modified-id="Mixup-6.1">Mixup</a></span></li><li><span><a href="#Test-Time-Augmentation" data-toc-modified-id="Test-Time-Augmentation-6.2">Test Time Augmentation</a></span></li></ul></li><li><span><a href="#Conclusion" data-toc-modified-id="Conclusion-7">Conclusion</a></span></li></ul></div>

# %%
import numpy as np
import torch

from pathlib import Path
from fastai2.vision.all import *
from fastai2.vision.widgets import *

# %%
# Set seed for reproducibility
seed = 9
torch.manual_seed(seed)
np.random.seed(seed)

# %%
# Although we don't condone it, let's silence warnings for the sake of readability
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ---------

# %% [markdown]
# # Objective

# %% [markdown]
# The goal of this notebook is to train an image classifier on the full [Food-101 dataset](https://data.vision.ee.ethz.ch/cvl/datasets_extra/food-101) using the `fastai2` library. We'll be implementing progressive resizing together with MixUp.

# %% [markdown]
# --------

# %% [markdown]
# # About Food-101

# %% [markdown]
# The [Food-101 dataset](https://data.vision.ee.ethz.ch/cvl/datasets_extra/food-101/) consists of 101 classes of food, with $750$ training images and $250$ validation images in each class, for a total of $75,750$ training images and $25,250$ validation images. Classes include foods like `apple pie, bibimbap, crab cakes, gyoza, nachos, and pho`.
#
# All images have been rescaled to have a maximum side length of $512$ pixels and training images have been deliberately left uncleaned (mostly in the form of intense colours and occassionally incorrect labels, according to the authors of the [original paper](https://data.vision.ee.ethz.ch/cvl/datasets_extra/food-101/)). Examining a few images from a handful of classes, we find that $512$ x $384$ (or the transpose) is a common image size. We also find that a non-trivial amount of labels are shockingly incorrect. For example, one of the images labeled "french toast" is an image of an omelette.

# %% [markdown]
# -----

# %% [markdown]
# # Train-valid-split

# %% [markdown]
# We've split the `Food-101` dataset beforehand into Imagenet-style `train/` and `valid/` folders following the `train.txt` and `test.txt` files provided in the dataset's `meta/` directory. This makes loading the data easier as with fastai.

# %% [markdown]
# --------

# %% [markdown]
# # Load Food-101 Dataset

# %% [markdown]
# Let's load and prep our dataset for modeling.

# %%
# Prep DataBlock with item & batch transforms
dblock = DataBlock(blocks=(ImageBlock(), CategoryBlock()),
                  get_items=get_image_files,
                  get_y=parent_label,
                  splitter=GrandparentSplitter(),
                  item_tfms=Resize(460),
                  batch_tfms=aug_transforms(size=224, min_scale=0.75))

# Load data
path = Path("./drive/My Drive/Food-101/dataset")
dls = dblock.dataloaders(path, bs=64)

# %%
# Verify the number of classes and images
print(dls.train.c, dls.train.n) 
print(dls.valid.c, dls.valid.n)
# Out:
# 101 75750
# 101 25250

# %%
# Inspect data. Yum! Looks good to me!
dls.show_batch(nrows=1, ncols=6)

# %% [markdown]
# # Data Augmentation

# %% [markdown]
# When we initalised our `DataBlock` above, we had to specify what types of transforms we wanted to use to augument our data. We used the standard transforms specified in `aug_transforms`. By specifying `min_scale=0.75`, we also enabled `RandomResizeCrop`, which is performed on the fly on each batch on the gpu (hence won't be shown below). Let's take a closer look at these transforms before we move on.

# %%
# Original plus eight augmentations for brightness/contrast, rotation, and a flip about x=0
dls.show_batch(nrows=2, unique=True)

# %% [markdown]
# ---------

# %% [markdown]
# # First Crack at a Better Model

# %% [markdown]
# Now that we have a solid baseline model, it's time to experiment and see if we can't do a little better! We'll experiment with `MixUp`.

# %% [markdown]
# ## Mixup

# %% [markdown]
# Mixup is an incredibly fascinating form of data augmentation. Given a training image, we select another image at random from the training set and take a linear combination of the two to produce a new image:
#
# ```
# new_image = t * original + (1 - t) * random
# ```
# The label for the new image is likewise a linear combination of the two labels. We select `t` at random from a beta distribution and set `t = max(t, 1-t)` to prevent duplicates. The resulting image is mostly like the original image, with a little bit of the random image thrown in. Naturally, this makes training much harder and will require many more epochs, however, the end results can be spectacularly good.
#
# The [original paper](https://arxiv.org/pdf/1710.09412.pdf) motivates mixup as a form of dataset-independent augmentation. Unlike other transforms that require careful selection (like reflections), mixup can safely be used on virtually any image dataset. There's also exciting possibilities for using mixup with text by applying it to a model's activations.
#
# We'll start by adding mixup to progressive resizing.

# %%
def get_dls(path, bs, size):
    """Return a set of train and valid dataloaders with images of a given size."""
    dblock = DataBlock(blocks=(ImageBlock(), CategoryBlock()),
                  get_items=get_image_files,
                  get_y=parent_label,
                  splitter=GrandparentSplitter(),
                  item_tfms=Resize(460),
                  batch_tfms=aug_transforms(size=size, min_scale=0.75))
    return dblock.dataloaders(path, bs=bs)

# %%
# First find a good base learning rate 
learn = cnn_learner(dls, resnet50, metrics=accuracy, cbs=MixUp)
learn.lr_find()
# Out:
# SuggestedLRs(lr_min=0.003981071710586548, lr_steep=0.0063095735386013985)

# %%
# Train on images of size 128
dls = get_dls(path, bs=128, size=128)
learn = cnn_learner(dls, resnet50, metrics=accuracy, cbs=MixUp)
learn.fine_tune(3, 6e-3, freeze_epochs=2)
learn.save("colab-resnet50-mixup-128")
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>3.422149</td>
#       <td>2.129638</td>
#       <td>0.466416</td>
#       <td>1:09:29</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>2.927582</td>
#       <td>1.697501</td>
#       <td>0.575485</td>
#       <td>10:56</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.618351</td>
#       <td>1.491802</td>
#       <td>0.613822</td>
#       <td>11:04</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>2.309196</td>
#       <td>1.047687</td>
#       <td>0.726812</td>
#       <td>11:06</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>2.065976</td>
#       <td>0.874766</td>
#       <td>0.769228</td>
#       <td>11:05</td>
#     </tr>
#   </tbody>
# </table>

# %%
 # Bump image size to 224
learn.dls = get_dls(path, bs=64, size=224)
learn.fine_tune(7, 1e-3)
learn.save("colab-resnet50-mixup-128-224")
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.048008</td>
#       <td>0.721509</td>
#       <td>0.812475</td>
#       <td>11:59</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.919421</td>
#       <td>0.669373</td>
#       <td>0.825426</td>
#       <td>12:18</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.909818</td>
#       <td>0.655826</td>
#       <td>0.829069</td>
#       <td>12:21</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.815260</td>
#       <td>0.607006</td>
#       <td>0.839050</td>
#       <td>12:20</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.764395</td>
#       <td>0.578671</td>
#       <td>0.848871</td>
#       <td>12:22</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.704971</td>
#       <td>0.547187</td>
#       <td>0.857267</td>
#       <td>12:17</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>1.661103</td>
#       <td>0.534153</td>
#       <td>0.860079</td>
#       <td>12:21</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>1.618192</td>
#       <td>0.523295</td>
#       <td>0.861426</td>
#       <td>12:18</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Bump to max image dim in our dataset
learn.dls = get_dls(path, bs=24, size=512)
learn.fine_tune(12, 1e-3)
learn.save("colab-resnet50-mixup-128-224-512")
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.956029</td>
#       <td>0.625894</td>
#       <td>0.832158</td>
#       <td>28:56</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.834170</td>
#       <td>0.556646</td>
#       <td>0.850218</td>
#       <td>36:46</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.797547</td>
#       <td>0.568092</td>
#       <td>0.848554</td>
#       <td>36:45</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.821231</td>
#       <td>0.556332</td>
#       <td>0.851842</td>
#       <td>36:45</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.823368</td>
#       <td>0.547210</td>
#       <td>0.853426</td>
#       <td>36:45</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.726747</td>
#       <td>0.526618</td>
#       <td>0.861149</td>
#       <td>36:46</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>1.725060</td>
#       <td>0.502312</td>
#       <td>0.864277</td>
#       <td>36:46</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>1.640648</td>
#       <td>0.471871</td>
#       <td>0.876673</td>
#       <td>36:44</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>1.546726</td>
#       <td>0.445084</td>
#       <td>0.879049</td>
#       <td>36:45</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>1.472502</td>
#       <td>0.424742</td>
#       <td>0.885228</td>
#       <td>36:45</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>1.479752</td>
#       <td>0.406659</td>
#       <td>0.889941</td>
#       <td>36:45</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>1.423364</td>
#       <td>0.403044</td>
#       <td>0.890059</td>
#       <td>36:44</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>1.415214</td>
#       <td>0.399687</td>
#       <td>0.894020</td>
#       <td>36:46</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Test Time Augmentation

# %% [markdown]
# The last thing we can do to squeeze out a bit of performance is use test time augmentation. We'll use fastai's default `tta()` method, which takes a weighted average of the model's prediction with the predictions from 4 augmented images.

# %%
preds, targets = learn.tta()
top_1 = accuracy(preds, targets).item()
top_2 = top_k_accuracy(preds, targets, k=2).item()
print(f"Top-1 Accuracy: {top_1: .4f} | Top-2 Accuracy {top_2: .4f}")
# Out:
# Top-1 Accuracy:  0.8995 | Top-2 Accuracy  0.9537

# %% [markdown]
# # Conclusion

# %% [markdown]
# Awesome! We're again seeing a final validation accuracy above `0.89` just like we did with label smoothing, and we're nearly breaking `0.90` accuracy when using `tta`.
